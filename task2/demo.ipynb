# %% [markdown]
# # Task 2. Named entity recognition + image classification

# %% [markdown]
# This notebook demonstrates how to prepare data to work with these models.

# %% [markdown]
# ## Initial loading of libraries

# %%
# Import required libraries and modules.
import warnings
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Import the models and pipeline
from ner.train_ner import train_ner
from image_classifier.train_image_classifier import train_image_classifier
from pipeline import pipeline

# %% [markdown]
# ## Initial preparation

# %%
# Ignore all warnings.
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Train models

# %%
# Train NER model.
train_ner()
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Map: 100%|██████████| 2000/2000 [00:00<00:00, 15747.81 examples/s]
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 04:09, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.000000</td>
#     </tr>
# ...

# %%
# Train image classification model (decided to choose AlexNet)
train_image_classifier()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 55, 55, 96)        34944
#
#  batch_normalization (BatchN  (None, 55, 55, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 192)       663744
#
#  batch_normalization_3 (Batc  (None, 13, 13, 192)      768
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       442624
#
# ...

# %% [markdown]
# ## Use pipeline

# %%
# Test variables
text="There is a cow in the picture."
image_path="image.jpg"

# %%
# Show our test data.
img = mpimg.imread(image_path)
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
plt.figtext(0.5, 0.01, text, wrap=True, horizontalalignment='center', fontsize=12)
plt.show()

# %%
# Check using pipeline.
pipeline(text, image_path)
# Out:
# Device set to use cuda:0
# Running NER on text...
# Animals mentioned in text: [{'entity': 'B-ANIMAL', 'score': 0.9999976, 'index': 4, 'word': 'cow', 'start': 11, 'end': 14}]
# Running image classification on image...
# 1/1 [==============================] - 1s 515ms/step
# Animal predicted from image: cow
# Pipeline result (True if match, False otherwise): True
# True

# %% [markdown]
# ## Some conclusions

# %% [markdown]
# As we can see, the pipeline effectively recognizes named entities (NER) and classifies images to check the correspondence of text descriptions to image content. For the NER model, a transformer-based model was used, as stated in the task. And for the animal classification model, I decided to use something a little more interesting than in the previous task and the choice fell on AlexNet, which was developed by a Ukrainian. That's all for the task, thank you for the opportunity)
